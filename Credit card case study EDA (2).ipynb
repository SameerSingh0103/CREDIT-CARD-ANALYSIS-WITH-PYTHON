# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
import os

# %%
os.chdir('C:\\Users\\gauta\\OneDrive\\Desktop\\Python Foundation Case Study 2 - Credit Card Case Study\\Case Study 2 - Credit Card Case Study')
os.chdir('C:\\Users\\gauta\\OneDrive\\Desktop\\Python Foundation Case Study 2 - Credit Card Case Study\\Case Study 2 - Credit Card Case Study')
os.chdir('C:\\Users\\gauta\\OneDrive\\Desktop\\Python Foundation Case Study 2 - Credit Card Case Study\\Case Study 2 - Credit Card Case Study')
os.chdir('C:\\Users\\gauta\\OneDrive\\Desktop\\Python Foundation Case Study 2 - Credit Card Case Study\\Case Study 2 - Credit Card Case Study')

# %%
Acqusition_df=pd.read_excel('credit_data.xlsx',sheet_name='Customer Acqusition')

# %%
Acqusition_df
# Out:
#      No Customer        Age        City   Product   Limit Company  \
# 0     1       A1  34.012349   BANGALORE      Gold  500000      C1
# 1     2       A2  50.497350    CALCUTTA    Silver  100000      C2
# 2     3       A3  35.855817      COCHIN  Platimum   10000      C3
# 3     4       A4  27.356821      BOMBAY  Platimum   10001      C4
# 4     5       A5  22.021249   BANGALORE  Platimum   10002      C5
# ..  ...      ...        ...         ...       ...     ...     ...
# 95   96      A96  71.083162     CHENNAI    Silver  100000     C19
# 96   97      A97  69.880658  TRIVANDRUM  Platimum   10000     C20
# 97   98      A98  20.951811    CALCUTTA  Platimum   10001     C21
# 98   99      A99  52.456908    CALCUTTA  Platimum   10002     C22
# 99  100     A100   8.729077      COCHIN    Silver  100000      C5
#
#           Segment
# 0   Self Employed
# 1    Salaried_MNC
# 2    Salaried_Pvt
# 3            Govt
# 4   Normal Salary
# ..            ...
# 95   Salaried_Pvt
# ...

# %%
Spend_df=pd.read_excel('credit_data.xlsx',sheet_name='Spend')

# %%
Spend_df
# Out:
#       Sl No: Customer      Month        Type         Amount
# 0          1       A1 2004-01-12   JEWELLERY  344054.980813
# 1          2       A1 2004-01-03       PETRO  467747.601626
# 2          3       A1 2004-01-15     CLOTHES   86878.954735
# 3          4       A1 2004-01-25        FOOD  269175.011875
# 4          5       A1 2005-01-17      CAMERA    3406.639477
# ...      ...      ...        ...         ...            ...
# 1495    1496      A67 2006-02-04  BUS TICKET  418316.710886
# 1496    1497      A68 2006-03-25  BUS TICKET  222182.008427
# 1497    1498      A69 2006-03-31  BUS TICKET  100049.079260
# 1498    1499      A70 2006-03-23  BUS TICKET  316308.254003
# 1499    1500      A71 2006-03-24  BUS TICKET  330483.743568
#
# [1500 rows x 5 columns]

# %%
Repayment_df=pd.read_excel('credit_data.xlsx',sheet_name='Repayment')

# %%
Repayment_df
# Out:
#       SL No: Customer      Month         Amount
# 0          1       A1 2004-01-12  338932.141919
# 1          2       A1 2004-01-03  131778.688758
# 2          3       A1 2004-01-15  485981.516736
# 3          4       A1 2004-01-25  452865.826385
# 4          5       A1 2005-01-17  154684.838196
# ...      ...      ...        ...            ...
# 1495    1496      A67 2005-05-09  461916.047960
# 1496    1497      A68 2006-05-10  269635.645462
# 1497    1498      A69 2006-07-11  181524.046445
# 1498    1499      A70 2005-08-12  308330.678493
# 1499    1500      A71 2004-09-13  125220.127871
#
# [1500 rows x 4 columns]

# %%
Acq_spend_df=pd.merge(left=Spend_df,right=Acqusition_df,how='left',left_on='Customer',right_on='Customer')

# %%
Acq_spend_df.head()
# Out:
#    Sl No: Customer      Month       Type         Amount  No        Age  \
# 0       1       A1 2004-01-12  JEWELLERY  344054.980813   1  34.012349
# 1       2       A1 2004-01-03      PETRO  467747.601626   1  34.012349
# 2       3       A1 2004-01-15    CLOTHES   86878.954735   1  34.012349
# 3       4       A1 2004-01-25       FOOD  269175.011875   1  34.012349
# 4       5       A1 2005-01-17     CAMERA    3406.639477   1  34.012349
#
#         City Product   Limit Company        Segment
# 0  BANGALORE    Gold  500000      C1  Self Employed
# 1  BANGALORE    Gold  500000      C1  Self Employed
# 2  BANGALORE    Gold  500000      C1  Self Employed
# 3  BANGALORE    Gold  500000      C1  Self Employed
# 4  BANGALORE    Gold  500000      C1  Self Employed

# %% [markdown]
# ### Removing the unwanted columns

# %%
Acq_spend_df.drop(['Sl No:','No'],axis=1,inplace= True)

# %%
Acq_Repayment_df=pd.merge(left=Repayment_df,right=Acqusition_df,how='left',left_on=['Customer'],right_on=['Customer'])

# %%
Acq_Repayment_df.head()
# Out:
#    SL No: Customer      Month         Amount  No        Age       City  \
# 0       1       A1 2004-01-12  338932.141919   1  34.012349  BANGALORE
# 1       2       A1 2004-01-03  131778.688758   1  34.012349  BANGALORE
# 2       3       A1 2004-01-15  485981.516736   1  34.012349  BANGALORE
# 3       4       A1 2004-01-25  452865.826385   1  34.012349  BANGALORE
# 4       5       A1 2005-01-17  154684.838196   1  34.012349  BANGALORE
#
#   Product   Limit Company        Segment
# 0    Gold  500000      C1  Self Employed
# 1    Gold  500000      C1  Self Employed
# 2    Gold  500000      C1  Self Employed
# 3    Gold  500000      C1  Self Employed
# 4    Gold  500000      C1  Self Employed

# %% [markdown]
# ### Removing the unwanted columns

# %%
Acq_Repayment_df.drop(['No'],axis=1,inplace= True)

# %% [markdown]
# ### Shape of the DataFrame

# %%
Acq_spend_df.shape
# Out:
# (1500, 10)

# %% [markdown]
# This DataFrame has 1500 rows and 15 columns

# %%
Acq_spend_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Customer  1500 non-null   object
#  1   Month     1500 non-null   datetime64[ns]
#  2   Type      1500 non-null   object
#  3   Amount    1500 non-null   float64
#  4   Age       1500 non-null   float64
#  5   City      1500 non-null   object
#  6   Product   1500 non-null   object
#  7   Limit     1500 non-null   int64
#  8   Company   1500 non-null   object
#  9   Segment   1500 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 117.3+ KB

# %% [raw]
# Total columns are 1500 and no missing values are present. Datatypes look fine

# %% [markdown]
# ### Datatype information

# %%
Acq_spend_df.dtypes
# Out:
# Customer            object
# Month       datetime64[ns]
# Type                object
# Amount             float64
# Age                float64
# City                object
# Product             object
# Limit                int64
# Company             object
# Segment             object
# dtype: object

# %% [raw]
# Datatype of all columns look fine

# %% [markdown]
# ### Describing the DataFrame

# %%
Acq_spend_df.describe().T
# Out:
#          count                        mean                  min  \
# Month     1500  2005-05-16 21:17:45.600000  2004-01-03 00:00:00
# Amount  1500.0                251257.26038             82.80178
# Age     1500.0                   35.721396             0.391231
# Limit   1500.0               297993.956667              10000.0
#
#                         25%                  50%                  75%  \
# Month   2004-04-25 00:00:00  2005-05-29 00:00:00  2006-03-26 00:00:00
# Amount        126743.823753        246712.644033        382643.654598
# Age               14.750376             34.06812            51.740878
# Limit              100000.0             500000.0             500000.0
#
#                         max            std
# Month   2006-12-03 00:00:00            NaN
# Amount        499980.650083  146590.486462
# Age               79.462556      21.808157
# Limit              500000.0  216239.376333

# %%
Acq_spend_df.describe(include='object').T
# Out:
#          count unique            top freq
# Customer  1500    100            A61   38
# Type      1500     15          PETRO  200
# City      1500      8      BANGALORE  299
# Product   1500      3           Gold  610
# Company   1500     41            C22  103
# Segment   1500      5  Normal Salary  441

# %% [raw]
# In Type, Petro has highest Frequency
# In city, Banglore has highest Freqeuncy
# In Product, Gold has highest Frequency
# In Company, C22 has highest Frequency

# %%
Acq_Repayment_df.describe().T
# Out:
#          count                           mean                  min  \
# SL No:  1500.0                          750.5                  1.0
# Month     1500  2005-05-24 01:18:43.199999872  2004-01-03 00:00:00
# Amount  1500.0                  248534.277849           123.461534
# Age     1500.0                      35.721396             0.391231
# Limit   1500.0                  297993.956667              10000.0
#
#                         25%                  50%                  75%  \
# SL No:               375.75                750.5              1125.25
# Month   2004-05-05 00:00:00  2005-05-29 00:00:00  2006-03-28 00:00:00
# Amount        119827.707132        251254.698598        369793.690157
# Age               14.750376             34.06812            51.740878
# Limit              100000.0             500000.0             500000.0
#
#                         max            std
# SL No:               1500.0     433.157015
# Month   2006-12-03 00:00:00            NaN
# ...

# %%
Acq_Repayment_df.describe(include='object').T
# Out:
#          count unique            top freq
# Customer  1500    100            A61   38
# City      1500      8      BANGALORE  299
# Product   1500      3           Gold  610
# Company   1500     41            C22  103
# Segment   1500      5  Normal Salary  441

# %% [raw]
# In Type, Petro has highest Frequency
# In city, Banglore has highest Freqeuncy
# In Product, Gold has highest Frequency
# In Company, C22 has highest Frequency

# %% [markdown]
# ### Checking inconsistencies  for Acq_spend_df

# %%
Cat_Acq_spend_df=Acq_spend_df.select_dtypes('object')

# %%
for i in Cat_Acq_spend_df:
    print(i.upper())
    print(end='\n')
    print(Acq_spend_df[i].value_counts())
    print(end='\n')
# Out:
# CUSTOMER
#
# Customer
# A61    38
# A60    38
# A22    33
# A21    33
# A41    31
#        ..
# A83     1
# A85     1
# A86     1
# A87     1
# A80     1
# Name: count, Length: 100, dtype: int64
#
# TYPE
#
# Type
# PETRO           200
# FOOD            160
# CAMERA          160
# AIR TICKET      147
# TRAIN TICKET    132
# SHOPPING        113
# BUS TICKET       99
# JEWELLERY        95
# CLOTHES          95
# RENTAL           76
# MOVIE TICKET     76
# BIKE             49
# AUTO             40
# CAR              30
# SANDALS          28
# Name: count, dtype: int64
#
# CITY
#
# City
# BANGALORE     299
# COCHIN        298
# CALCUTTA      251
# BOMBAY        215
# CHENNAI       130
# TRIVANDRUM    112
# PATNA          98
# DELHI          97
# Name: count, dtype: int64
#
# PRODUCT
#
# Product
# Gold        610
# Platimum    570
# Silver      320
# Name: count, dtype: int64
#
# COMPANY
#
# Company
# C22    103
# C21     84
# C8      77
# C9      77
# C10     77
# C11     77
# C12     77
# ...

# %% [markdown]
# There are no inconsistencies in the Dataframe

# %% [markdown]
# ### Checking inconsistencies for Acq_Repayment_df

# %%
Cat_Acq_Repayment_df= Acq_Repayment_df.select_dtypes('object')

# %%
for i in Cat_Acq_Repayment_df:
    print(i.upper())
    print(end='\n')
    print(Acq_Repayment_df[i].value_counts())
    print(end='\n')
# Out:
# CUSTOMER
#
# Customer
# A61    38
# A60    38
# A22    33
# A21    33
# A41    31
#        ..
# A83     1
# A85     1
# A86     1
# A87     1
# A80     1
# Name: count, Length: 100, dtype: int64
#
# CITY
#
# City
# BANGALORE     299
# COCHIN        298
# CALCUTTA      251
# BOMBAY        215
# CHENNAI       130
# TRIVANDRUM    112
# PATNA          98
# DELHI          97
# Name: count, dtype: int64
#
# PRODUCT
#
# Product
# Gold        610
# Platimum    570
# Silver      320
# Name: count, dtype: int64
#
# COMPANY
#
# Company
# C22    103
# C21     84
# C8      77
# C9      77
# C10     77
# C11     77
# C12     77
# C7      76
# C6      76
# C18     71
# C19     71
# C20     71
# C23     69
# C13     64
# C14     64
# C17     53
# C16     53
# C15     53
# C24     50
# C5      46
# C25     34
# C1      18
# C4      12
# C3      12
# C2      11
# C32      2
# C27      2
# C33      2
# C26      2
# C31      2
# C30      2
# C29      2
# C28      2
# C34      1
# C36      1
# ...

# %% [markdown]
# No inconsistencies in the Acq_Repayment_df are found.

# %% [markdown]
# ### Checking missing values for Acq_spend_df

# %%
Acq_spend_df.isnull().sum()
# Out:
# Customer    0
# Month       0
# Type        0
# Amount      0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %% [markdown]
# There are no missing values in Acq_spend_df

# %% [markdown]
# ### Checking missing values in  Acq_Repayment_df

# %%
Acq_Repayment_df.isnull().sum()
# Out:
# SL No:      0
# Customer    0
# Month       0
# Amount      0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %% [markdown]
# There are no missing values in  Acq_Repayment_df

# %% [markdown]
# ### Checking Duplicate values in  Acq_spend_df

# %%
 Acq_spend_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicate values are founf in  Acq_spend_df

# %% [markdown]
# ### Checking Duplicate values in Acq_Repayment_df

# %%
Acq_Repayment_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicate values are founf in  Acq_Repayment_df

# %% [markdown]
# ### Univariate Analysis on  Acq_spend_df

# %% [markdown]
# #### Plotting boxplots for all continous columns

# %%
Conti_Acq_spend_df=Acq_spend_df.select_dtypes('number')

# %%
for i in Conti_Acq_spend_df.columns:
    plt.figure(figsize=(6,6))
    Conti_Acq_spend_df[i].plot(kind='box')

# %% [markdown]
# ### Univariate Analysis on Acq_Repayment_df

# %%
Conti_Acq_Repayment_df=Acq_Repayment_df.select_dtypes('number')

# %%
Conti_Acq_Repayment_df
# Out:
#       SL No:         Amount        Age   Limit
# 0          1  338932.141919  34.012349  500000
# 1          2  131778.688758  34.012349  500000
# 2          3  485981.516736  34.012349  500000
# 3          4  452865.826385  34.012349  500000
# 4          5  154684.838196  34.012349  500000
# ...      ...            ...        ...     ...
# 1495    1496  461916.047960  57.841495  500000
# 1496    1497  269635.645462  30.829863  100000
# 1497    1498  181524.046445  15.216474   10000
# 1498    1499  308330.678493  11.259760   10001
# 1499    1500  125220.127871  76.824468   10002
#
# [1500 rows x 4 columns]

# %%
for i in Conti_Acq_Repayment_df.columns:
    plt.figure(figsize=(6,6))
    Conti_Acq_Repayment_df[i].plot(kind='box')

# %% [markdown]
# No columns have outliers

# %% [markdown]
# ### Histograms for all numeric columns in Acq_spend_df

# %%
for i in Conti_Acq_spend_df.columns:
    plt.figure(figsize=(5,6))
    sns.histplot(data=Acq_spend_df[i])

# %% [markdown]
# ### Histograms for all numeric columns in Acq_Repayment_df

# %%
for i in Conti_Acq_spend_df.columns:
    plt.figure(figsize=(6,6))
    sns.histplot(data=Conti_Acq_spend_df[i])

# %% [markdown]
# ### Histograms for all numeric columns in Acq_Repayment_df

# %%
for i in Conti_Acq_Repayment_df.columns:
    plt.figure(figsize=(6,6))
    sns.histplot(data=Conti_Acq_Repayment_df[i])

# %% [markdown]
# ### Univariate analysis for categorical columns in Acq_spend_df

# %%
for i in Cat_Acq_spend_df:
    plt.figure(figsize=(10,6))
    sns.countplot(data=Cat_Acq_spend_df,x=i)
    plt.xticks(rotation=50)

# %% [markdown]
# ### Univariate analysis for categorical columns in Acq_Repayment_df

# %%
for i in Cat_Acq_Repayment_df:
    plt.figure(figsize=(10,6))
    sns.countplot(data=Cat_Acq_Repayment_df,x=i)
    plt.xticks(rotation=90)

# %% [markdown]
# ### Bivariate Analysis for Acq_spend_df

# %%
Conti_Acq_spend_df.corr()
# Out:
#           Amount       Age     Limit
# Amount  1.000000 -0.032981  0.029452
# Age    -0.032981  1.000000 -0.110980
# Limit   0.029452 -0.110980  1.000000

# %%
plt.figure(figsize=(5,5))
sns.heatmap(data=Conti_Acq_spend_df.corr(),annot= True,cmap= 'Blues',vmax=1,vmin=-1)
# Out:
# <Axes: >

# %% [markdown]
# ### Bivariate Analysis for Acq_Repayment_df

# %%
Conti_Acq_Repayment_df.corr()
# Out:
#           SL No:    Amount       Age     Limit
# SL No:  1.000000 -0.021805  0.087896  0.050924
# Amount -0.021805  1.000000 -0.010197  0.053392
# Age     0.087896 -0.010197  1.000000 -0.110980
# Limit   0.050924  0.053392 -0.110980  1.000000

# %%
plt.figure(figsize=(5,4))
sns.heatmap(data=Conti_Acq_Repayment_df.corr(),annot= True,vmax=1,vmin=-1,cmap='Blues')
# Out:
# <Axes: >

# %% [raw]
#  Age and limit have least coorelation

# %%
Acq_spend_df
# Out:
#      Customer      Month        Type         Amount        Age        City  \
# 0          A1 2004-01-12   JEWELLERY  344054.980813  34.012349   BANGALORE
# 1          A1 2004-01-03       PETRO  467747.601626  34.012349   BANGALORE
# 2          A1 2004-01-15     CLOTHES   86878.954735  34.012349   BANGALORE
# 3          A1 2004-01-25        FOOD  269175.011875  34.012349   BANGALORE
# 4          A1 2005-01-17      CAMERA    3406.639477  34.012349   BANGALORE
# ...       ...        ...         ...            ...        ...         ...
# 1495      A67 2006-02-04  BUS TICKET  418316.710886  57.841495     CHENNAI
# 1496      A68 2006-03-25  BUS TICKET  222182.008427  30.829863  TRIVANDRUM
# 1497      A69 2006-03-31  BUS TICKET  100049.079260  15.216474    CALCUTTA
# 1498      A70 2006-03-23  BUS TICKET  316308.254003  11.259760      BOMBAY
# 1499      A71 2006-03-24  BUS TICKET  330483.743568  76.824468      BOMBAY
#
#        Product   Limit Company        Segment
# ...

# %% [markdown]
# ## 1. In the above dataset,

# %% [markdown]
# ###  a. In case age is less than 18, replace it with mean of age values.

# %%
Acq_spend_df.Age = np.where(Acq_spend_df.Age<18, round(Acq_spend_df.Age.mean()),Acq_spend_df.Age)

# %% [markdown]
# ###  b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit. Customer’s limit provided in acquisition table is the per transaction limit on his card

# %%
Acq_spend_df.Amount= np.where(Acq_spend_df.Amount>Acq_spend_df.Limit,Acq_spend_df.Limit/0.50,Acq_spend_df.Amount)

# %% [markdown]
# ###  c. Incase the repayment amount is more than the limit, replace the repayment with the limit

# %%
Acq_Repayment_df.Amount=np.where(Acq_Repayment_df.Amount>Acq_Repayment_df.Limit,Acq_Repayment_df.Limit,Acq_Repayment_df.Amount)

# %% [markdown]
# ## 2. From the above dataset create the following summaries:

# %% [markdown]
# ###  a. How many distinct customers exist?

# %%
Acq_spend_df.Customer.value_counts().count()
# Out:
# 100

# %% [markdown]
# ### b. How many distinct categories exist?

# %%
Acq_spend_df.Product.value_counts().count()
# Out:
# 3

# %% [markdown]
# ###  c. What is the average monthly spend by customers?

# %%
Acq_spend_df['month_of_date'] = Acq_spend_df['Month'].dt.month

# %%
Acq_spend_df
# Out:
#      Customer      Month        Type         Amount        Age        City  \
# 0          A1 2004-01-12   JEWELLERY  344054.980813  34.012349   BANGALORE
# 1          A1 2004-01-03       PETRO  467747.601626  34.012349   BANGALORE
# 2          A1 2004-01-15     CLOTHES   86878.954735  34.012349   BANGALORE
# 3          A1 2004-01-25        FOOD  269175.011875  34.012349   BANGALORE
# 4          A1 2005-01-17      CAMERA    3406.639477  34.012349   BANGALORE
# ...       ...        ...         ...            ...        ...         ...
# 1495      A67 2006-02-04  BUS TICKET  418316.710886  57.841495     CHENNAI
# 1496      A68 2006-03-25  BUS TICKET  200000.000000  30.829863  TRIVANDRUM
# 1497      A69 2006-03-31  BUS TICKET   20000.000000  36.000000    CALCUTTA
# 1498      A70 2006-03-23  BUS TICKET   20002.000000  36.000000      BOMBAY
# 1499      A71 2006-03-24  BUS TICKET   20004.000000  76.824468      BOMBAY
#
#        Product   Limit Company        Segment  month_of_date
# ...

# %%
Acq_spend_df[['Amount','month_of_date']].groupby(by=['month_of_date']).mean()
# Out:
#                       Amount
# month_of_date
# 1              194249.638550
# 2              193228.339748
# 3              191203.309689
# 4              183785.437557
# 5              185038.212022
# 6              200048.062096
# 7              220202.655728
# 8              203882.203587
# 9              184903.234028
# 10             140843.558265
# 11             201520.277700
# 12             158498.704074

# %% [markdown]
# ###  d. What is the average monthly repayment by customers?

# %%
Acq_Repayment_df['Date_of_month']=Acq_Repayment_df.Month.dt.month

# %%
Acq_Repayment_df[['Date_of_month','Amount']].groupby(by=['Date_of_month']).mean()
# Out:
#                       Amount
# Date_of_month
# 1              165905.237443
# 2              160934.572612
# 3              172041.556360
# 4              145718.823377
# 5              182598.051975
# 6              159447.404034
# 7              145543.401628
# 8              175245.744288
# 9              118936.574626
# 10             173375.652849
# 11             179681.424484
# 12             137534.986755

# %% [markdown]
# ###  e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month? (Profit is defined as interest earned on Monthly Profit. Monthly Profit = Monthly repayment – Monthly spend. Interest is earned only on positive profits and not on negative amounts)

# %%
Acq_Repayment_df
# Out:
#       SL No: Customer      Month         Amount        Age        City  \
# 0          1       A1 2004-01-12  338932.141919  34.012349   BANGALORE
# 1          2       A1 2004-01-03  131778.688758  34.012349   BANGALORE
# 2          3       A1 2004-01-15  485981.516736  34.012349   BANGALORE
# 3          4       A1 2004-01-25  452865.826385  34.012349   BANGALORE
# 4          5       A1 2005-01-17  154684.838196  34.012349   BANGALORE
# ...      ...      ...        ...            ...        ...         ...
# 1495    1496      A67 2005-05-09  461916.047960  57.841495     CHENNAI
# 1496    1497      A68 2006-05-10  100000.000000  30.829863  TRIVANDRUM
# 1497    1498      A69 2006-07-11   10000.000000  15.216474    CALCUTTA
# 1498    1499      A70 2005-08-12   10001.000000  11.259760      BOMBAY
# 1499    1500      A71 2004-09-13   10002.000000  76.824468      BOMBAY
#
#        Product   Limit Company        Segment  Date_of_month
# ...

# %% [markdown]
# ###  f. What are the top 5 product types?

# %%
Acq_spend_df.Type.value_counts().sort_values(ascending=False).head(5)
# Out:
# Type
# PETRO           200
# FOOD            160
# CAMERA          160
# AIR TICKET      147
# TRAIN TICKET    132
# Name: count, dtype: int64

# %% [markdown]
# Top 5 product types in terms of Quantity

# %%
Acq_spend_df[['Type','Amount']].groupby(by=['Type']).sum().sort_values(by=['Amount'],ascending=False).astype('int64')
# Out:
#                 Amount
# Type
# PETRO         39512808
# CAMERA        34993117
# FOOD          30944574
# AIR TICKET    29765799
# TRAIN TICKET  24815497
# SHOPPING      21013166
# CLOTHES       17110544
# BUS TICKET    16232624
# RENTAL        15249252
# JEWELLERY     14895345
# MOVIE TICKET  14577387
# BIKE           8873354
# AUTO           6643550
# CAR            6239136
# SANDALS        5598590

# %% [markdown]
# Top 5 Product Type in terms of Amount

# %% [markdown]
# ### g. Which city is having maximum spend?

# %%
Acq_spend_df[['City','Amount']].groupby(by=['City']).sum().astype('int64')
# Out:
#               Amount
# City
# BANGALORE   59727667
# BOMBAY      40132850
# CALCUTTA    46807385
# CHENNAI     25356162
# COCHIN      58699769
# DELHI       18786410
# PATNA       18666254
# TRIVANDRUM  18288250

# %% [markdown]
# ### h. Which age group is spending more money?

# %%
Acq_spend_df['Age_Group']=np.where(((Acq_spend_df.Age.astype(int) >= 18) & (Acq_spend_df.Age.astype(int) < 25)), 'Youth',np.where(((Acq_spend_df.Age.astype(int) >= 25) & (Acq_spend_df.Age.astype(int) < 65)), 'Adult','Senior'))

# %%
Acq_spend_df[['Age_Group','Amount']].groupby(by=['Age_Group']).sum().astype('int64')
# Out:
#               Amount
# Age_Group
# Adult      225101184
# Senior      46172374
# Youth       15191193

# %% [markdown]
# Adult AgeGroup is spending most of the Amount

# %% [markdown]
# ### Who are the top 10 customers in terms of repayment?

# %%
Acq_spend_df[['Amount','Customer']].groupby(by=['Customer']).sum().astype('int64').sort_values(by='Amount',ascending=False).head(10)
# Out:
#             Amount
# Customer
# A60       10567875
# A61       10135574
# A13        9697930
# A42        8687951
# A40        8443861
# A44        8399371
# A38        8233458
# A45        7723286
# A43        7486463
# A29        7429748

# %% [markdown]
# ## 3. Calculate the city wise spend on each product on yearly basis. Also include a graphical representation for the same

# %%
Acq_spend_df['Year']=Acq_spend_df.Month.dt.year

# %%
City_Wise_Spend=Acq_spend_df.pivot_table(index=['Product','City'],values='Amount',columns=['Year'],aggfunc='sum').astype('int64')

# %%
City_Wise_Spend_1=Acq_spend_df[['Amount','Year','City','Product']].groupby(by=['City','Product','Year']).sum().astype('int64').sort_values(by='Amount',ascending=False).head(10)

# %%
Gold_df=City_Wise_Spend.iloc[:8]

# %% [markdown]
# #### Spend on Gold for  all Cities

# %%
Gold_df.plot(kind='barh')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Spend on Platimum for all Cities

# %%
Platimum_df=City_Wise_Spend.iloc[8:16]

# %%
Platimum_df.plot(kind='barh')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Spend on Platimum for all Cities

# %%
Silver_df=City_Wise_Spend.iloc[16:24]

# %%
Silver_df.plot(kind='barh')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 4. Create graphs for

# %% [markdown]
# ####  a. Monthly comparison of total spends, city wise

# %%
Spend_citywise=Acq_spend_df[['City','Amount']].groupby(by='City').sum().astype('int64')

# %%
plt.figure(figsize=(5,7))
Spend_citywise.plot(kind='pie',subplots=True)
plt.legend(bbox_to_anchor=(1,1.3), loc='upper left')
plt.show()

# %% [markdown]
# ###  b. Comparison of yearly spend on air tickets

# %%
Airticket_Spend=Acq_spend_df[Acq_spend_df.Type=='AIR TICKET'].iloc[:,[2,-1,3]]

# %%
Airticket_Spend_df=Airticket_Spend[['Amount','Year']].groupby(by='Year',).sum().astype('int64')

# %%
plt.figure(figsize=(5,7))
Airticket_Spend_df.plot(kind='barh',subplots=True)
# Out:
# array([<Axes: title={'center': 'Amount'}, ylabel='Year'>], dtype=object)

# %% [markdown]
# ###  c. Comparison of monthly spend for each product (look for any seasonality that exists in terms of spend)

# %%
Monthly_Spend_product=Acq_spend_df.loc[:,['Amount','month_of_date','Product']]

# %%
Monthly_Spend_product_df=Monthly_Spend_product.pivot_table(index=['Product'],values='Amount',columns=['month_of_date'],aggfunc='sum').astype('int64')

# %%
Monthly_Spend_product_df
# Out:
# month_of_date        1         2         3         4         5        6   \
# Product
# Gold           35380431  27365779  23026120  14458677  21791613  6377463
# Platimum       18711477  11903252  10947687   7124912  10595624  2770784
# Silver         13701215   6719312  10194156   5984225   6470786  2054444
#
# month_of_date       7        8        9        10        11       12
# Product
# Gold           4643751  5563528  4533602  2442833  10238728  1937272
# Platimum       2861519  2096858  2158502  1100780   4385520  1500682
# Silver         1743241   902664  1073829   400006   2303454  1000008

# %%
Monthly_Spend_product_df_plot=Monthly_Spend_product_df.T

# %%
Monthly_Spend_product_df_plot
# Out:
# Product            Gold  Platimum    Silver
# month_of_date
# 1              35380431  18711477  13701215
# 2              27365779  11903252   6719312
# 3              23026120  10947687  10194156
# 4              14458677   7124912   5984225
# 5              21791613  10595624   6470786
# 6               6377463   2770784   2054444
# 7               4643751   2861519   1743241
# 8               5563528   2096858    902664
# 9               4533602   2158502   1073829
# 10              2442833   1100780    400006
# 11             10238728   4385520   2303454
# 12              1937272   1500682   1000008

# %%
for i in Monthly_Spend_product_df_plot.columns:
    plt.figure(figsize=(5,7))
    Monthly_Spend_product_df_plot[i].plot(kind='pie')

# %% [markdown]
# ### You need to find top 10 customers for each city in terms of their repayment amount by different products and by different time periods i.e. year or month. The user should be able to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the function should automatically take these inputs while identifying the top 10 customers.

# %%
Acq_Repayment_df.Date_of_month.value_counts()
# Out:
# Date_of_month
# 1     319
# 5     266
# 2     228
# 3     219
# 4     150
# 11     84
# 7      49
# 8      49
# 6      48
# 9      40
# 10     24
# 12     24
# Name: count, dtype: int64

# %%
Acq_Repayment_df.groupby(['Customer','City','Product','Date_of_month']).Amount.sum().reset_index().sort_values('Amount',ascending=False).head(10)
# Out:
#     Customer       City   Product  Date_of_month        Amount
# 307      A42     BOMBAY      Gold              1  2.999181e+06
# 311      A42     BOMBAY      Gold              5  2.988995e+06
# 291      A40   CALCUTTA  Platimum              1  2.923243e+06
# 467      A60   CALCUTTA      Gold              1  2.706474e+06
# 192      A29   CALCUTTA      Gold              5  2.602146e+06
# 175      A27    CHENNAI      Gold              5  2.214800e+06
# 477      A61     COCHIN      Gold              1  2.140209e+06
# 315      A43  BANGALORE      Gold              1  2.108499e+06
# 54       A15   CALCUTTA      Gold              5  2.101543e+06
# 299      A41     COCHIN  Platimum              1  2.090637e+06

# %%
Acq_Repayment_df
# Out:
#       SL No: Customer      Month         Amount        Age        City  \
# 0          1       A1 2004-01-12  338932.141919  34.012349   BANGALORE
# 1          2       A1 2004-01-03  131778.688758  34.012349   BANGALORE
# 2          3       A1 2004-01-15  485981.516736  34.012349   BANGALORE
# 3          4       A1 2004-01-25  452865.826385  34.012349   BANGALORE
# 4          5       A1 2005-01-17  154684.838196  34.012349   BANGALORE
# ...      ...      ...        ...            ...        ...         ...
# 1495    1496      A67 2005-05-09  461916.047960  57.841495     CHENNAI
# 1496    1497      A68 2006-05-10  100000.000000  30.829863  TRIVANDRUM
# 1497    1498      A69 2006-07-11   10000.000000  15.216474    CALCUTTA
# 1498    1499      A70 2005-08-12   10001.000000  11.259760      BOMBAY
# 1499    1500      A71 2004-09-13   10002.000000  76.824468      BOMBAY
#
#        Product   Limit Company        Segment  Date_of_month
# ...

# %%
def top10(product,Timeperiod):
    if  product=='Gold' and Timeperiod=='monthly':
        result=CR.query('Product=="Gold"').groupby(['City',CR.Month.dt.year.rename('Year'),CR.Month.dt.month,'Customer'])[['Repayment_Amount']].sum().sort_values(by=['City','Year','Month','Repayment_Amount'],ascending=[True,True,True,False]).reset_index()
        return result.groupby(['City','Year','Month']).head(10)
    if  product=='Gold' and Timeperiod=='yearly':
        result=CR.query('Product=="Gold"').groupby(['City',CR.Month.dt.year.rename('Year'),'Customer'])[['Repayment_Amount']].sum().sort_values(by=['City','Year','Repayment_Amount'],ascending=[True,True,False]).reset_index()
        return result.groupby(['City','Year','Month']).head(10)
    if  product=='Silver' and Timeperiod=='monthly':
        result=CR.query('Product=="Silver"').groupby(['City',CR.Month.dt.year.rename('Year'),CR.Month.dt.month,'Customer'])[['Repayment_Amount']].sum().sort_values(by=['City','Year','Month','Repayment_Amount'],ascending=[True,True,True,False]).reset_index()
        return result.groupby(['City','Year','Month']).head(10)
    if  product=='Silver' and Timeperiod=='yearly':
        result=CR.query('Product=="Silver"').groupby(['City',CR.Month.dt.year.rename('Year'),'Customer'])[['Repayment_Amount']].sum().sort_values(by=['City','Year','Repayment_Amount'],ascending=[True,True,False]).reset_index()
        return result.groupby(['City','Year','Month']).head(10)
    if  product=='Platinum' and Timeperiod=='monthly':
        result=CR.query('Product=="Platimum"').groupby(['City',CR.Month.dt.year.rename('Year'),CR.Month.dt.month,'Customer'])[['Repayment_Amount']].sum().sort_values(by=['City','Year','Month','Repayment_Amount'],ascending=[True,True,True,False]).reset_index()
        return result.groupby(['City','Year','Month']).head(10)
    if  product=='Platinum' and Timeperiod=='yearly':
        result=CR.query('Product=="Platimum"').groupby(['City',CR.Month.dt.year.rename('Year'),'Customer'])[['Repayment_Amount']].sum().sort_values(by=['City','Year','Repayment_Amount'],ascending=[True,True,False]).reset_index()
        return result.groupby(['City','Year','Month']).head(10)

# %%
print(Gold,'monthly')
# Out:
# Product            Gold
# month_of_date
# 1              35380431
# 2              27365779
# 3              23026120
# 4              14458677
# 5              21791613
# 6               6377463
# 7               4643751
# 8               5563528
# 9               4533602
# 10              2442833
# 11             10238728
# 12              1937272 monthly
